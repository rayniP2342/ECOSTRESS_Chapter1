# %% [markdown]
# # This code will compares AmeriFlux seasonal ET to ECOSTRESS and OpenET methods.
#
# You will need all of the data ready to use in csv format:
# - AmeriFlux ET data
# - ECOSTRESS ET data
# - OpenET ET data
